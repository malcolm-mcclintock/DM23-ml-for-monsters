# %%
import numpy as np
import math
import random

p_heads = np.linspace(0,1,100)
p_tails = 1-p_heads

class SetGenerator:
    def __init__(trials=100,probability):
        self.trials = trials
        self.probability = probability
    def rand_set(trials=self.trials):
        return [random.random() for i in range(trials)]
    rand_set()
# Out:
# [0.9348190691899502,
#  0.3074459715589406,
#  0.8868975047760608,
#  0.16119676808065642,
#  0.42727653259217757,
#  0.9843690523949247,
#  0.07158149932078162,
#  0.08969489337789671,
#  0.5321693092909991,
#  0.9101750561483979,
#  0.8139337045047351,
#  0.28443201030211274,
#  0.9119262038724598,
#  0.9006002403755635,
#  0.641499259761405,
#  0.2864148224290308,
#  0.06385549540228141,
#  0.72825195087102,
#  0.2547978827732008,
#  0.7627372083562636,
#  0.5297650717737132,
#  0.7030028441669541,
#  0.346862612358133,
#  0.5528991862260667,
#  0.266527195293237,
#  0.2349677913202316,
#  0.7225903034866095,
#  0.03853684910270505,
#  0.8384063444841137,
#  0.39075294576840414,
#  0.38827413839409974,
#  0.33147600597106897,
#  0.26759739359577395,
#  0.7386195125497378,
#  0.1909206178506926,
#  0.9929956191444145,
#  0.9500064083108005,
#  0.3228149468158936,
#  0.5168143630003171,
#  0.19033406122653096,
#  0.4076943607456821,
#  0.5185311106199282,
#  0.7721251168792996,
# ...
